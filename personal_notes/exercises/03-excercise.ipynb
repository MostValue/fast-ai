# %%
from fastbook import *
from fastai.vision.all import *

matplotlib.rc('image', cmap = "Greys")

# %%
path = untar_data(URLs.MNIST_SAMPLE)

# %%
Path.BASE_PATH = path

# %%
path.ls()
# Out:
# (#3) [Path('valid'),Path('train'),Path('labels.csv')]

# %%
(path/'train').ls()
# Out:
# (#2) [Path('train/3'),Path('train/7')]

# %%
threes = (path/'train'/'3').ls().sorted()
sevens = (path/'train'/'7').ls().sorted()

# %%
im3_path = threes[23]
im3 = Image.open(im3_path)
im3
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=28x28>

# %% [markdown]
# We are using the python image library to open and view our photos.

# %%
array(im3)[10:20,10:20]
# Out:
# array([[  0,   0,   0,   0,   0,   0,   3,  63, 254, 215],
#        [  0,   0,   0,   0,   0,   0, 136, 254, 254, 109],
#        [  0,   0,  55,  57, 127, 211, 253, 248,  75,   1],
#        [  0, 153, 252, 254, 254, 226, 141,  57,   0,   0],
#        [  0, 144, 254, 254, 218,   0,   0,   0,   0,   0],
#        [  0,   0,  57, 207, 254, 231,  42,   0,   0,   0],
#        [  0,   0,   0,  24, 170, 254, 206,   0,   0,   0],
#        [  0,   0,   0,   0,  56, 254, 217,   3,   0,   0],
#        [  0,   0,   0,   0,   0, 226, 254,  56,   0,   0],
#        [  0,   0,   0,   0,  18, 213, 232,  25,   0,   0]], dtype=uint8)

# %%
im3_t = tensor(im3)
df = pd.DataFrame(im3_t)
df.style.set_properties(**{'font-size':'6pt'}).background_gradient('Greys')
# Out:
# <style type="text/css">
# #T_f7102_row0_col0, #T_f7102_row0_col1, #T_f7102_row0_col2, #T_f7102_row0_col3, #T_f7102_row0_col4, #T_f7102_row0_col5, #T_f7102_row0_col6, #T_f7102_row0_col7, #T_f7102_row0_col8, #T_f7102_row0_col9, #T_f7102_row0_col10, #T_f7102_row0_col11, #T_f7102_row0_col12, #T_f7102_row0_col13, #T_f7102_row0_col14, #T_f7102_row0_col15, #T_f7102_row0_col16, #T_f7102_row0_col17, #T_f7102_row0_col18, #T_f7102_row0_col19, #T_f7102_row0_col20, #T_f7102_row0_col21, #T_f7102_row0_col22, #T_f7102_row0_col23, #T_f7102_row0_col24, #T_f7102_row0_col25, #T_f7102_row0_col26, #T_f7102_row0_col27, #T_f7102_row1_col0, #T_f7102_row1_col1, #T_f7102_row1_col2, #T_f7102_row1_col3, #T_f7102_row1_col4, #T_f7102_row1_col5, #T_f7102_row1_col6, #T_f7102_row1_col7, #T_f7102_row1_col8, #T_f7102_row1_col9, #T_f7102_row1_col10, #T_f7102_row1_col11, #T_f7102_row1_col12, #T_f7102_row1_col13, #T_f7102_row1_col14, #T_f7102_row1_col15, #T_f7102_row1_col16, #T_f7102_row1_col17, #T_f7102_row1_col18, #T_f7102_row1_col19, #T_f7102_row1_col20, #T_f7102_row1_col21, #T_f7102_row1_col22, #T_f7102_row1_col23, #T_f7102_row1_col24, #T_f7102_row1_col25, #T_f7102_row1_col26, #T_f7102_row1_col27, #T_f7102_row2_col0, #T_f7102_row2_col1, #T_f7102_row2_col2, #T_f7102_row2_col3, #T_f7102_row2_col4, #T_f7102_row2_col5, #T_f7102_row2_col6, #T_f7102_row2_col7, #T_f7102_row2_col8, #T_f7102_row2_col9, #T_f7102_row2_col10, #T_f7102_row2_col11, #T_f7102_row2_col12, #T_f7102_row2_col13, #T_f7102_row2_col14, #T_f7102_row2_col15, #T_f7102_row2_col16, #T_f7102_row2_col17, #T_f7102_row2_col18, #T_f7102_row2_col19, #T_f7102_row2_col20, #T_f7102_row2_col21, #T_f7102_row2_col22, #T_f7102_row2_col23, #T_f7102_row2_col24, #T_f7102_row2_col25, #T_f7102_row2_col26, #T_f7102_row2_col27, #T_f7102_row3_col0, #T_f7102_row3_col1, #T_f7102_row3_col2, #T_f7102_row3_col3, #T_f7102_row3_col4, #T_f7102_row3_col5, #T_f7102_row3_col6, #T_f7102_row3_col7, #T_f7102_row3_col8, #T_f7102_row3_col9, #T_f7102_row3_col10, #T_f7102_row3_col11, #T_f7102_row3_col12, #T_f7102_row3_col13, #T_f7102_row3_col14, #T_f7102_row3_col15, #T_f7102_row3_col16, #T_f7102_row3_col17, #T_f7102_row3_col18, #T_f7102_row3_col19, #T_f7102_row3_col20, #T_f7102_row3_col21, #T_f7102_row3_col22, #T_f7102_row3_col23, #T_f7102_row3_col24, #T_f7102_row3_col25, #T_f7102_row3_col26, #T_f7102_row3_col27, #T_f7102_row4_col0, #T_f7102_row4_col1, #T_f7102_row4_col2, #T_f7102_row4_col3, #T_f7102_row4_col4, #T_f7102_row4_col5, #T_f7102_row4_col6, #T_f7102_row4_col7, #T_f7102_row4_col8, #T_f7102_row4_col9, #T_f7102_row4_col10, #T_f7102_row4_col11, #T_f7102_row4_col12, #T_f7102_row4_col13, #T_f7102_row4_col14, #T_f7102_row4_col15, #T_f7102_row4_col16, #T_f7102_row4_col17, #T_f7102_row4_col18, #T_f7102_row4_col19, #T_f7102_row4_col20, #T_f7102_row4_col21, #T_f7102_row4_col22, #T_f7102_row4_col23, #T_f7102_row4_col24, #T_f7102_row4_col25, #T_f7102_row4_col26, #T_f7102_row4_col27, #T_f7102_row5_col0, #T_f7102_row5_col1, #T_f7102_row5_col2, #T_f7102_row5_col3, #T_f7102_row5_col4, #T_f7102_row5_col5, #T_f7102_row5_col6, #T_f7102_row5_col7, #T_f7102_row5_col8, #T_f7102_row5_col9, #T_f7102_row5_col17, #T_f7102_row5_col18, #T_f7102_row5_col19, #T_f7102_row5_col20, #T_f7102_row5_col21, #T_f7102_row5_col22, #T_f7102_row5_col23, #T_f7102_row5_col24, #T_f7102_row5_col25, #T_f7102_row5_col26, #T_f7102_row5_col27, #T_f7102_row6_col0, #T_f7102_row6_col1, #T_f7102_row6_col2, #T_f7102_row6_col3, #T_f7102_row6_col4, #T_f7102_row6_col5, #T_f7102_row6_col6, #T_f7102_row6_col7, #T_f7102_row6_col8, #T_f7102_row6_col9, #T_f7102_row6_col19, #T_f7102_row6_col20, #T_f7102_row6_col21, #T_f7102_row6_col22, #T_f7102_row6_col23, #T_f7102_row6_col24, #T_f7102_row6_col25, #T_f7102_row6_col26, #T_f7102_row6_col27, #T_f7102_row7_col0, #T_f7102_row7_col1, #T_f7102_row7_col2, #T_f7102_row7_col3, #T_f7102_row7_col4, #T_f7102_row7_col5, #T_f7102_row7_col6, #T_f7102_row7_col7, #T_f7102_row7_col8, #T_f7102_row7_col9, #T_f7102_row7_col13, #T_f7102_row7_col20, #T_f7102_row7_col21, #T_f7102_row7_col22, #T_f71 ...
